# %%
# Rock Paper Scissors

Let's play the famous game against our computer.

https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors

The use of functions is recommended

## Goals
1. Use of loop
2. Data capture by console
3. Use if-elif-else
4. Use of try-except
5. Definition of functions. Modular programming
6. Logical operators.
7. Print
8. Import modules

# %%
max_games = 7
to_win = 4

import random

comp_wins = 0
player_wins = 0
ties = 0
games_played = 0

def Choose_Option():
    user_choice = input("Choose Rock, Paper or Scissors: ")
    if user_choice in ["Rock", "rock", "r", "R"]:
        user_choice = "r"
    elif user_choice in ["Paper", "paper", "p", "P"]:
        user_choice = "p"
    elif user_choice in ["Scissors", "scissors", "s", "S"]:
        user_choice = "s"
    else:
        print("I don't understand, try again.")
        Choose_Option()
    return user_choice

def Computer_Option():
    comp_choice = random.randint(1, 3)
    if comp_choice == 1:
        comp_choice = "r"
    elif comp_choice == 2:
        comp_choice = "p"
    else:
        comp_choice = "s"
    return comp_choice


while games_played < max_games:
    games_played += 1
    print("")
    
    user_choice = Choose_Option()
    comp_choice = Computer_Option()

    print("")
    
    if user_choice == "r":
        if comp_choice == "r":
            print("You chose rock. The computer chose rock. You tied.")
            ties += 1
        
        elif comp_choice == "p":
            print("You chose rock. The computer chose paper. You lose.")
            comp_wins += 1
            
        elif comp_choice == "s":
            print("You chose rock. The computer chose scissors. You win.")
            player_wins += 1

    elif user_choice == "p":
        if comp_choice == "r":
            print("You chose paper. The computer chose rock. You win.")
            player_wins += 1
        
        elif comp_choice == "p":
            print("You chose paper. The computer chose paper. You tied.")
            ties += 1
            
            
        elif comp_choice == "s":
            print("You chose paper. The computer chose scissors. You lose.")
            comp_wins += 1

    elif user_choice == "s":
        if comp_choice == "r":
            print("You chose scissors. The computer chose rock. You lose.")
            comp_wins += 1
        
        elif comp_choice == "p":
            print("You chose scissors. The computer chose paper. You win.")
            player_wins += 1
            
        elif comp_choice == "s":
            print("You chose scissors. The computer chose scissors. You tied.")
            ties += 1

    print("")
    print("Games played: " + str(games_played))
    print("Ties: " + str(ties))
    print("Player wins: " + str(player_wins))
    print("Computer wins: " + str(comp_wins))
    print("")
    
   
    if (comp_wins < 4) | (player_wins < 4):
        pass

if comp_wins > player_wins:
    print('CPU WON')
elif player_wins > comp_wins:
    print('YOU WON')
else:
    print ('MATCH DRAWN')

# %%
#BONUS#

import random



while True:
    max_games = input('Choose an odd number of games to play: ')
    max_games = int(max_games)
    if (max_games % 2 == 0):
        print ('Number not odd, please try again.')
    elif(max_games == max_games):
        print("ok")
        break
    
moves =['rock','paper','scissors','spock','lizzard']

comp_wins = 0
player_wins = 0
ties = 0
games_played = 0


def Computer_Option():
    comp_choice = random.randint(1, 5)
    if comp_choice == 1:
        comp_choice = "r"
    elif comp_choice == 2:
        comp_choice = "p"
    elif comp_choice == 3:
        comp_choice = "s"
    elif comp_choice == 4:
        comp_choice = 'sp'
    else:
        comp_choice = "l"
    return comp_choice

def Choose_Option():
    user_choice = input("Choose Rock, Paper, Scissors, Spock or Lizzard: ")
    if user_choice in ["Rock", "rock", "r", "R"]:
        user_choice = "r"
    elif user_choice in ["Paper", "paper", "p", "P"]:
        user_choice = "p"
    elif user_choice in ["Scissors", "scissors", "s", "S"]:
        user_choice = "s"
    elif user_choice in ["Spock", "spock", "sp", "Sp"]:
        user_choice = "sp"
    elif user_choice in ["Lizzard", "lizzard", "l", "L"]:
        user_choice = "l"
    else:
        print("I don't understand, try again.")
        Choose_Option()
    return user_choice

while games_played < max_games:
    games_played += 1
    print("")
    
    user_choice = Choose_Option()
    comp_choice = Computer_Option()

    print("")
    
    if user_choice == "r":
        if comp_choice == "r":
            print("You chose rock. The computer chose rock. You tied.")
            ties += 1
        
        elif comp_choice == "p":
            print("You chose rock. The computer chose paper. You lose.")
            comp_wins += 1
            
        elif comp_choice == "s":
            print("You chose rock. The computer chose scissors. You win.")
            player_wins += 1
        
        elif comp_choice == "sp":
            print("You chose rock. The computer chose spock. You lose.")
            comp_wins += 1
        
        elif comp_choice == "l":
            print("You chose rock. The computer chose lizzard. You win.")
            player_wins += 1
        
    elif user_choice == "p":
        if comp_choice == "r":
            print("You chose paper. The computer chose rock. You win.")
            player_wins += 1
        
        elif comp_choice == "p":
            print("You chose paper. The computer chose paper. You tied.")
            ties += 1
            
        elif comp_choice == "s":
            print("You chose paper. The computer chose scissors. You lose.")
            comp_wins += 1
                 
        elif comp_choice == "sp":
            print("You chose paper. The computer chose spock. You win.")
            player_wins += 1
             
        elif comp_choice == "l":
            print("You chose paper. The computer chose lizzard. You lose.")
            comp_wins += 1

    elif user_choice == "s":
        if comp_choice == "r":
            print("You chose scissors. The computer chose rock. You lose.")
            comp_wins += 1
        
        elif comp_choice == "p":
            print("You chose scissors. The computer chose paper. You win.")
            player_wins += 1
            
        elif comp_choice == "s":
            print("You chose scissors. The computer chose scissors. You tied.")
            ties += 1
            
        elif comp_choice == "sp":
            print("You chose scissors. The computer chose spock. You lose.")
            comp_wins += 1
         
        elif comp_choice == "l":
            print("You chose scissors. The computer chose lizzard. You win.")
            player_wins += 1
            
    elif user_choice == "sp":
        if comp_choice == "r":
            print("You chose spock. The computer chose rock. You win.")
            player_wins += 1
        
        elif comp_choice == "p":
            print("You chose spock. The computer chose paper. You lose.")
            comp_wins += 1
            
        elif comp_choice == "sp":
            print("You chose spock. The computer chose spock. You tied.")
            ties += 1
        
        elif comp_choice == "s":
            print("You chose spock. The computer chose scissors. You win.")
            player_wins += 1
        
        elif comp_choice == "l":
            print("You chose spock. The computer chose lizzard. You lose.")
            comp_wins += 1
            
    elif user_choice == "l":
        if comp_choice == "r":
            print("You chose lizzard. The computer chose rock. You lose.")
            comp_wins += 1
        
        elif comp_choice == "p":
            print("You chose lizzard. The computer chose paper. You win.")
            player_wins += 1
            
        elif comp_choice == "l":
            print("You chose lizzard. The computer chose lizzard. You tied.")
            ties += 1
            
        elif comp_choice == "s":
            print("You chose lizzard. The computer chose scissors. You lost.")
            comp_wins += 1
              
        elif comp_choice == "sp":
            print("You chose lizzard. The computer chose spock. You win.")
            player_wins += 1

    print("")
    print("Games played: " + str(games_played))
    print("Ties: " + str(ties))
    print("Player wins: " + str(player_wins))
    print("Computer wins: " + str(comp_wins))
    print("")
    
if comp_wins > player_wins:
    print('CPU WON')
elif player_wins > comp_wins:
    print('YOU WON')
else:
    print ('MATCH DRAWN')
# Out:
# Choose an odd number of games to play: 3
# ok
#
# Choose Rock, Paper, Scissors, Spock or Lizzard: s
#
# You chose scissors. The computer chose scissors. You tied.
#
# Games played: 1
# Ties: 1
# Player wins: 0
# Computer wins: 0
#
#
# Choose Rock, Paper, Scissors, Spock or Lizzard: l
#
# You chose lizzard. The computer chose rock. You lose.
#
# Games played: 2
# Ties: 1
# Player wins: 0
# Computer wins: 1
#
#
# Choose Rock, Paper, Scissors, Spock or Lizzard: p
#
# You chose paper. The computer chose lizzard. You lose.
#
# Games played: 3
# Ties: 1
# Player wins: 0
# Computer wins: 2
#
# CPU WON
